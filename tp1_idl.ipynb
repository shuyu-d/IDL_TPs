# %% [markdown]
# <a href="https://colab.research.google.com/github/shuyu-d/IDL_TP/blob/master/tp1_idl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to deep learning - TP1**
#
# L’objectif de ce notebook Python est de s’assurer que vous savez utiliser CoLab et de vous familiariser avec certains concepts mathématiques de base dont vous aurez besoin pour commencer à travailler sur les sujets de l’apprentissage profond.
#
# À différents endroits, vous verrez la mention «A COMPLETER». Suivez les instructions indiquées à ces endroits.
# Si vous n’arrivez pas à comprendre ce qui est demandé ou comment compléter une section, n’hésitez pas à poser des questions pendant les séances de TP.

# %% [markdown]
# ### Importer les librairies et les fonctions d'utilité.

# %%
# Imports math library
# Imports plotting library
import numpy as np
import matplotlib.pyplot as plt
# Plot the random points x on the 2D plan. 
# Each point x will be colored according the h(x) function value
def plot_h_2d( X, Y):  
    fig, ax = plt.subplots(1, 1, figsize=(5,5))
    Ymax = max(abs(Y)) # get the maximal value of |h(x)| 
    for i in range(X.shape[0]):
        if Y[i] > 0:
            color = 'red'
            alpha_value = Y[i]/Ymax
        else:
            color = 'blue'
            alpha_value = 1 
        ax.scatter(X[i,0],X[i,1], alpha=alpha_value, \
                 marker='o', facecolors='none', edgecolors=color)
    ax.set_xlabel('x_1'); ax.set_ylabel('x_2')
    return fig, ax

# Plot the random points x on the 2D plan. 
# Each point x will be colored according the h(x) function value.
# At the same time, the point x_star on H(w,b) closest to x will be shown 
#   (when |x| is large enough, to limit the number of x_star to be plotted)
def plot2_h_2d( X, Y, X_star):  
    fig, ax = plt.subplots(1, 1, figsize=(5,5))
    Ymax = max(abs(Y)) # get the maximal value of |h(x)| 
    for i in range(X.shape[0]):
        if Y[i] > 0:
            color = 'red'
            alpha_value = Y[i]/Ymax
        else:
            color = 'blue'
            alpha_value = 1 
        ax.scatter(X[i,0],X[i,1], alpha=alpha_value, \
                 marker='o', facecolors='none', edgecolors=color)
    for i in range(X_star.shape[0]):
        ax.scatter(X_star[i,0],X_star[i,1], alpha=1, \
                 marker='x', color='k')
    ax.set_xlabel('x_1'); ax.set_ylabel('x_2')
    return fig, ax

# %% [markdown]
# ### Composition d'une application linéaire avec la fonction $\sigma$
#
# **Exercice 1.6**
# On considère la fonction $$h(x) = \sigma(w^T x - b)$$
# définie sur le plan 2-dimensionnel, où $w\in\mathbb{R}^2$ et $b\in\mathbb{R}$ sont les paramètres donés, et $\sigma$ est une fonction réelle définie par $\sigma(z) = z$ si $z\geq 0$ et sinon $\sigma(z)=0$.
#
# Pour un vecteur d'entrée $x=(x_{1}, x_{2})^T$, la valeur de la fonction $h(x)$ s'écrit :
#
# \begin{equation}h(x)= \sigma(w_1 x_1 + w_2 x_2 -b).\end{equation}

# %% [markdown]
# #### Représentation des paramètres $w$ et $b$

# %%
w = np.array([2, 3]) # we use a numpy array to represent a vector on the 2D plan
b = 0 # scalar

# %% [markdown]
# #### Implémenter les fonctions $\sigma(\cdot)$ et $h(\cdot)$

# %%
def sigma_value(z): 
    # -- A COMPLETER -- 
    # replace the line below to compute the value sigma(z)     
    value = -1  
    return value

# Define a linear function with just one input, x
def function_h(x, w, b):
    # -- A COMPLETER -- 
    # replace the line below to compute the value y = h(x) 
    value = 0
    return value

# Test the function value with random points x on the 2D plan 
#  The points (or vecteurs in the course) are implemented as numpy arrays of size 1xp, 
#  where p (p=2 here) is the vector space dimension.
x = np.array([-0.5, -2])
print('h(%.2f,%.2f) = '%(x[0],x[1]), function_h(x, w, b))

x = np.array([-0.5, 2])
print('h(%.2f,%.2f) = '%(x[0],x[1]), function_h(x, w, b))
# Out:
# h(-0.50,-2.00) =  0
# h(-0.50,2.00) =  0

# %% [markdown]
# #### Calculer les valeurs de $h(x)$ pour un numbre de points $x$ aléatoires autour de l'origine

# %%
# Generate N points on the 2D plan randomly
# Set the random seed of np.random to a fixed value, say, seed=3 
fixed_seed = 3
np.random.seed( fixed_seed )
N = 1000
X = np.random.normal(size=[N, 2], scale=1)

# For each row x_i in X, compute the function value h(x_i)
Y = []
for i in range(X.shape[0]): 
    x_i = X[i,:]
    y_i = function_h(x_i, w, b)
    Y.append(y_i)
    if i > N-10: 
        print('h(%.2f,%.2f) = '%(x_i[0],x_i[1]), function_h(x_i, w, b))
# Out:
# h(0.04,1.04) =  0
# h(1.06,-0.95) =  0
# h(0.71,-0.46) =  0
# h(1.45,-0.31) =  0
# h(1.03,-1.06) =  0
# h(0.75,-1.40) =  0
# h(0.08,-1.65) =  0
# h(-0.17,-0.82) =  0
# h(-1.00,0.21) =  0

# %% [markdown]
# ### Visualisation des résultats
#
# Ensuite, on visualise ces points $x$ sur le plan 2D. Chaque point sera coloré selon la valeur de la fonction h(x).
#
# (Note: les $\sigma$ et $h(x)$ sont à modifier et compléter, et les figures initiales ci-dessous n'ont aucun rapport avec cet exercice)
#
# **Questions**
# 1. Quelles sont vos observations du résultat visualisé ici ?

# %%
# vectorize the python list Y into a numpy array (a vector)
Y = np.array(Y) # this facilitates operations with absolute values (abs), etc
fig, ax = plot_h_2d(X,Y)

# %% [markdown]
# #### Visualiser les solutions de l'Exercice 1.5 sur la même figure
#
# **Questions**
# 2. Quelle est interprétation des points $x^*$ (les points sont marqué par les croix 'x') ?
# 3. Quel est le rapport entre l'ensemble contenant $x^*$ et $w$ ?

# %%
def compute_xstar(x, w, b): 
    # -- A COMPLETER ---
    # replace the line below by the expression of x_star on H(w,b) that you find in Exercice 1.5. 
    xstar = x
    return xstar 

# For each row x_i in X, compute the function value h(x_i)
Y = [] ; X_star = []
for i in range(X.shape[0]): 
    x_i = X[i,:]
    y_i = function_h(x_i, w, b)
    Y.append(y_i) 
    if np.linalg.norm(x_i) > 0.8:
        x_star = compute_xstar(x_i, w, b)
        X_star.append( x_star )
    if i > N-10: 
        print('h(%.2f,%.2f) = '%(x_i[0],x_i[1]), function_h(x_i, w, b))

# Vectorize the python list Y into a numpy array (a vector) to facilitate the plot function here.
Y = np.array(Y) 
X_star = np.array(X_star)

fig, ax = plot2_h_2d(X,Y, X_star)
# Out:
# h(0.04,1.04) =  0
# h(1.06,-0.95) =  0
# h(0.71,-0.46) =  0
# h(1.45,-0.31) =  0
# h(1.03,-1.06) =  0
# h(0.75,-1.40) =  0
# h(0.08,-1.65) =  0
# h(-0.17,-0.82) =  0
# h(-1.00,0.21) =  0
